# %% [markdown]
# <a href="https://colab.research.google.com/github/apmai/market-data/blob/main/Market_Holidays_%26_Timings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Learn how to  get NSE trading holidays days & market timing Info through free API. This process is very easy and efficient. It does not require any kind of broker login, Just run few line of code and get trading holiday list.
#
# API Doc URL :  https://upstox.com/developer/api-docu...
# https://www.youtube.com/watch?v=-kldflAnW98

# %%
# !git clone https://github.com/apmai/market-data.git
# Out:
# Cloning into 'market-data'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (4/4), done.

# %%
# !git add .
# !git commit -m "Update notebook"
# !git push origin master
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
import requests
import pandas as pd

# To get market timings for a specific date
# Date is in YYYY-MM-DD format
# We do not need to be an Upstox customer to use this API calls
# https://upstox.com/developer/api-documentation/get-market-holidays


url = 'https://api.upstox.com/v2/market/holidays'
headers = {'Accept': 'application/json'}

response = requests.get(url, headers=headers)

if response.status_code == 200:
    data = response.json()
    # Process the JSON response
    print(data)
else:
    print("Failed to retrieve data. Status code:", response.status_code)

holidays = response.json()
# Out:
# {'status': 'success', 'data': [{'date': '2024-01-01', 'description': 'New Year Day', 'holiday_type': 'TRADING_HOLIDAY', 'closed_exchanges': [], 'open_exchanges': [{'exchange': 'MCX', 'start_time': 1704079800000, 'end_time': 1704108600000}, {'exchange': 'NSE', 'start_time': 1704080700000, 'end_time': 1704103200000}, {'exchange': 'NFO', 'start_time': 1704080700000, 'end_time': 1704103200000}, {'exchange': 'CDS', 'start_time': 1704079800000, 'end_time': 1704108600000}, {'exchange': 'BSE', 'start_time': 1704080700000, 'end_time': 1704103200000}, {'exchange': 'BCD', 'start_time': 1704079800000, 'end_time': 1704108600000}, {'exchange': 'BFO', 'start_time': 1704080700000, 'end_time': 1704103200000}]}, {'date': '2024-01-20', 'description': 'Special Trading', 'holiday_type': 'TRADING_HOLIDAY', 'closed_exchanges': ['MCX', 'CDS', 'BCD'], 'open_exchanges': [{'exchange': 'NSE', 'start_time': 1705722300000, 'end_time': 1705744800000}, {'exchange': 'NFO', 'start_time': 1705722300000, 'end_time': 17
# ...

# %%
df_holidays = pd.DataFrame(holidays['data'])
df_holidays['date'] = pd.to_datetime(df_holidays['date']).apply(lambda x: x.date())
df_holidays
# Out:
#           date                          description        holiday_type  \
# 0   2024-01-01                         New Year Day     TRADING_HOLIDAY
# 1   2024-01-20                      Special Trading     TRADING_HOLIDAY
# 2   2024-01-22              Ram Temple consecration     TRADING_HOLIDAY
# 3   2024-01-26                         Republic Day     TRADING_HOLIDAY
# 4   2024-02-19  Chhatrapati Shivaji Maharaj Jayanti  SETTLEMENT_HOLIDAY
# 5   2024-03-08                       Maha Shivratri     TRADING_HOLIDAY
# 6   2024-03-25                                 Holi     TRADING_HOLIDAY
# 7   2024-03-29                          Good Friday     TRADING_HOLIDAY
# 8   2024-04-01                  Annual Bank Closing  SETTLEMENT_HOLIDAY
# 9   2024-04-09                          Gudhi Padwa  SETTLEMENT_HOLIDAY
# 10  2024-04-11            Eid-Ul-Fitr (Ramadan Eid)     TRADING_HOLIDAY
# 11  2024-04-17                           Ram Navami     TRADING_HOLIDAY
# ...

# %%
df_holidays = df_holidays[df_holidays['holiday_type'] == 'TRADING_HOLIDAY']
df_holidays
# Out:
#           date                description     holiday_type  \
# 0   2024-01-01               New Year Day  TRADING_HOLIDAY
# 1   2024-01-20            Special Trading  TRADING_HOLIDAY
# 2   2024-01-22    Ram Temple consecration  TRADING_HOLIDAY
# 3   2024-01-26               Republic Day  TRADING_HOLIDAY
# 5   2024-03-08             Maha Shivratri  TRADING_HOLIDAY
# 6   2024-03-25                       Holi  TRADING_HOLIDAY
# 7   2024-03-29                Good Friday  TRADING_HOLIDAY
# 10  2024-04-11  Eid-Ul-Fitr (Ramadan Eid)  TRADING_HOLIDAY
# 11  2024-04-17                 Ram Navami  TRADING_HOLIDAY
# 12  2024-05-01             Maharastra Day  TRADING_HOLIDAY
# 14  2024-06-17                  Bakri Eid  TRADING_HOLIDAY
# 15  2024-07-17                   Moharram  TRADING_HOLIDAY
# 16  2024-08-15           Independence Day  TRADING_HOLIDAY
# 19  2024-10-02     Mahatma Gandhi Jayanti  TRADING_HOLIDAY
# 20  2024-11-01         Diwali Laxmi Pujan  TRADING_HOLIDAY
# ...

# %%
url = 'https://api.upstox.com/v2/market/holidays/2024-11-15'
headers = {'Accept': 'application/json'}

response = requests.get(url, headers=headers)

if response.status_code == 200:
    data = response.json()
    # Process the JSON response
    print(data)
else:
    print("Failed to retrieve data. Status code:", response.status_code)

holidays = response.json()
holidays
# Out:
# {'status': 'success', 'data': [{'date': '2024-11-15', 'description': 'Guru Nanak Jayanti', 'holiday_type': 'TRADING_HOLIDAY', 'closed_exchanges': ['NSE', 'NFO', 'CDS', 'BSE', 'BCD', 'BFO'], 'open_exchanges': [{'exchange': 'MCX', 'start_time': 1731670200000, 'end_time': 1731695100000}]}]}
# {'status': 'success',
#  'data': [{'date': '2024-11-15',
#    'description': 'Guru Nanak Jayanti',
#    'holiday_type': 'TRADING_HOLIDAY',
#    'closed_exchanges': ['NSE', 'NFO', 'CDS', 'BSE', 'BCD', 'BFO'],
#    'open_exchanges': [{'exchange': 'MCX',
#      'start_time': 1731670200000,
#      'end_time': 1731695100000}]}]}

# %%
# To get market timings for a specific date
# Date is in YYYY-MM-DD format
# We do not need to be an Upstox customer to use this API calls

import requests

# url = "https://api.upstox.com/v2/market/timings/:date"

url = "https://api.upstox.com/v2/market/timings/2024-11-15"

payload={}
headers = {
  'Accept': 'application/json'
}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"status":"success","data":[{"exchange":"MCX","start_time":1731670200000,"end_time":1731695100000}]}

# %%
import requests
# Date is in YYYY-MM-DD format

# url = "https://api.upstox.com/v2/market/timings/:date"

url = "https://api.upstox.com/v2/market/timings/2024-02-18" # No Colon to be used before Date

payload={}
headers = {
  'Accept': 'application/json'
}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Result Data is EMPTY if Market is not open
# Out:
# {"status":"success","data":[]}

# %%
# To get market timings for a specific date

# url = "https://api.upstox.com/v2/market/timings/:date"
# Date is in YYYY-MM-DD format

url = "https://api.upstox.com/v2/market/timings/2024-03-08"

payload={}
headers = {
  'Accept': 'application/json'
}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Result Data is EMPTY if Market is not open
# Out:
# {"status":"success","data":[{"exchange":"MCX","start_time":1709897400000,"end_time":1709922300000}]}
